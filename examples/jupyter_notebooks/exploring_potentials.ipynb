# %% [markdown]
# # Import libraries

# %%
#from matplotlib.pyplot import * 
#from numpy import *
import pynested_fit as pynf
import os
import time

# %matplotlib inline
#%matplotlib widget
#%matplotlib notebook

# %%
pynf.__version__
# Out:
# '5.6.4'

# %%
# Define the present path as root path
root_path = os.getcwd()
print(root_path)
# Out:
# /Users/martino/Nextcloud/CNRS/work/programs/nested_fit/nested_fit/examples/jupyter_notebooks
# /Users/martino/Nextcloud/CNRS/work/programs/nested_fit/nested_fit/examples/jupyter_notebooks/LJ3

# %% [markdown]
# # Lennar-Jones cluster with 3 atoms

# %% [markdown]
# ## Change directory and run the analysis

# %%
# Go to a define analysis
path = root_path+'/LJ3'

# Go to a define analysis
if not os.path.exists(path):
    os.makedirs(path)
os.chdir(path)

# %%
#### Define inputs using a "latex" function
conf = pynf.Configurator(
    calculation_mode= 'POTENTIAL',    # Calculation mode
    expressions=['ENERGY_LJ_3D_PBC'], # Chosen potential
    params={                          # Parameters of the potential
        'r_0': {'value': 0.5,  'step': -1, 'min': -3,   'max': 3, 'fixed': True, 'npar': 1},
        'x_1': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 2},
        'y_1': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 3},
        'z_1': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 4},
        'x_2': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 5},
        'y_2': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 6},
        'z_2': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 7},
        'x_3': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 8},
        'y_3': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 9},
        'z_3': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 10},
    },
    livepoints=1000,                  # Number of live points
    search_method='SLICE_SAMPLING',   # Search method
    search_params=(0.5, 3),           # Parameters of chosen method
    conv_method='ENERGY_MAX',          # Selection method for the convergence criterion
    conv_accuracy=-10,                # log(Z) final accuracy
    conv_parameter=0.01,              # Minimal temperature valid for the calculation
)

# %%
# Run the code

# For visualising the progress of the execution use this command
#out = conf.sample(output_mode='live')

# For visualising the progress graphycally (not working in Google Colab), use
# out = conf.sample(output_mode='full')

# If nothing shows, use simply the command (symlink to created or version to be used)
# Create the command to run nested fit in case of need
# run_nested_fit = os.system('nested_fit'+pynf.__version__)
# run_nested_fit

# For silently running the code and save the raw output in a dictionnary, use this command
out = conf.sample(output_mode='none')

# %% [markdown]
# ## Visualize the results

# %%
# Load the nested output data
# The available parameters and other variables that can be plotted are listed
an=pynf.Analysis()
# Out:
# Current path =  .
# ['r_0', 'x_1', 'y_1', 'z_1', 'x_2', 'y_2', 'z_2', 'x_3', 'y_3', 'z_3']
# Index(['weight', 'lnlikelihood', 'r_0', 'x_1', 'y_1', 'z_1', 'x_2', 'y_2',
#        'z_2', 'x_3', 'y_3', 'z_3'],
#       dtype='str')
# Available parameters : ['weight', 'lnlikelihood', 'r_0', 'x_1', 'y_1', 'z_1', 'x_2', 'y_2', 'z_2', 'x_3', 'y_3', 'z_3']
# Index(['density', 'energy'], dtype='str')
# Available parameters: ['density', 'energy']
# Available energies: 31932

# %%
# Plot the parameter convergence
# Colored regions correspond to the high value of the weights
an.plot_Cv(T_min=0.01,T_max=0.6,at_cluster=True,N=3)

# %% [markdown]
# # Lennar-Jones cluster with 7 atoms

# %% [markdown]
# ## Change directory and run the analysis

# %%
# Go to a define analysis
path = root_path+'/LJ7'


# Go to a define analysis
if not os.path.exists(path):
    os.makedirs(path)
os.chdir(path)

# %%
#### Define inputs using a "latex" function
conf = pynf.Configurator(
    calculation_mode= 'POTENTIAL',    # Calculation mode
    expressions=['ENERGY_LJ_3D_PBC'], # Chosen potential
    params={                          # Parameters of the potential
        'r_0': {'value': 0.5,  'step': -1, 'min': -3,   'max': 3, 'fixed': True, 'npar': 1},
        'x_1': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 2},
        'y_1': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 3},
        'z_1': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 4},
        'x_2': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 5},
        'y_2': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 6},
        'z_2': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 7},
        'x_3': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 8},
        'y_3': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 9},
        'z_3': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 10},
        'x_4': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 11},
        'y_4': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 12},
        'z_4': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 13},
        'x_5': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 14},
        'y_5': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 15},
        'z_5': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 16},
        'x_6': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 17},
        'y_6': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 18},
        'z_6': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 19},
        'x_7': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 20},
        'y_7': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 21},
        'z_7': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 22},
    },
    livepoints=1000,                  # Number of live points
    search_method='SLICE_SAMPLING',   # Search method
    search_params=(0.5, 3),           # Parameters of chosen method
    conv_method='ENERGY_MAX',          # Selection method for the convergence criterion
    conv_accuracy=-10,                # log(Z) final accuracy
    conv_parameter=0.01,              # Minimal temperature valid for the calculation
)

# %%
# Run the code
t0 = time.perf_counter() # start timer

# For visualising the progress of the execution use this command
#out = conf.sample(output_mode='live')

# For visualising the progress graphycally (not working in Google Colab), use
# out = conf.sample(output_mode='full')

# If nothing shows, use simply the command (symlink to created or version to be used)
# Create the command to run nested fit in case of need
# run_nested_fit = os.system('nested_fit'+pynf.__version__)
# run_nested_fit

# For silently running the code and save the raw output in a dictionnary, use this command
out = conf.sample(output_mode='none')

t1 = time.perf_counter() # end timer

print(f"Nested sampling completed in {t1 - t0:.2f} seconds.")
# Out:
# Nested sampling completed in 17.83 seconds.

# %% [markdown]
# ## Visualize the results

# %%
# Load the nested output data
# The available parameters and other variables that can be plotted are listed
an=pynf.Analysis()
# Out:
# Current path =  .
# ['r_0', 'x_1', 'y_1', 'z_1', 'x_2', 'y_2', 'z_2', 'x_3', 'y_3', 'z_3', 'x_4', 'y_4', 'z_4', 'x_5', 'y_5', 'z_5', 'x_6', 'y_6', 'z_6', 'x_7', 'y_7', 'z_7']
# Index(['weight', 'lnlikelihood', 'r_0', 'x_1', 'y_1', 'z_1', 'x_2', 'y_2',
#        'z_2', 'x_3', 'y_3', 'z_3', 'x_4', 'y_4', 'z_4', 'x_5', 'y_5', 'z_5',
#        'x_6', 'y_6', 'z_6', 'x_7', 'y_7', 'z_7'],
#       dtype='str')
# Available parameters : ['weight', 'lnlikelihood', 'r_0', 'x_1', 'y_1', 'z_1', 'x_2', 'y_2', 'z_2', 'x_3', 'y_3', 'z_3', 'x_4', 'y_4', 'z_4', 'x_5', 'y_5', 'z_5', 'x_6', 'y_6', 'z_6', 'x_7', 'y_7', 'z_7']
# Index(['density', 'energy'], dtype='str')
# Available parameters: ['density', 'energy']
# Available energies: 95596

# %%
an.plot_weights()

# %%
# Plot the parameter convergence
# Colored regions correspond to the high value of the weights
an.plot_Cv(T_min=0.01,T_max=0.6,at_cluster=True,N=3)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/martino/Nextcloud/CNRS/work/programs/nested_fit/nested_fit/pynested_fit/nested_res.py:1532: RuntimeWarning: invalid value encountered in scalar divide
#   U[i] = np.sum(dos*en*np.exp(-en/T[i]))/Z[i] # Internal energy <E>
# /Users/martino/Nextcloud/CNRS/work/programs/nested_fit/nested_fit/pynested_fit/nested_res.py:1533: RuntimeWarning: invalid value encountered in scalar divide
#   en2 = np.sum(dos*en**2*np.exp(-en/T[i]))/Z[i] # <E^2>

# %% [markdown]
# # Lennar-Jones cluster with 7 atoms (normalized box)

# %% [markdown]
# ## Change directory and run the analysis

# %%
# Go to a define analysis
path = root_path+'/LJ7_norm'


# Go to a define analysis
if not os.path.exists(path):
    os.makedirs(path)
os.chdir(path)

# %%
#### Define inputs using a "latex" function
conf = pynf.Configurator(
    calculation_mode= 'POTENTIAL',    # Calculation mode
    expressions=['ENERGY_LJ_3D_PBC_NORM'], # Chosen potential
    params={                          # Parameters of the potential
        'r_0': {'value': 0.08333333,  'step': -1, 'min': -3,   'max': 3, 'fixed': True, 'npar': 1},
        'x_1': {'value': 0.,  'step': -1, 'min': 0,   'max': 1, 'npar': 2},
        'y_1': {'value': 0.,  'step': -1, 'min': 0,   'max': 1, 'npar': 3},
        'z_1': {'value': 0.,  'step': -1, 'min': 0,   'max': 1, 'npar': 4},
        'x_2': {'value': 0.,  'step': -1, 'min': 0,   'max': 1, 'npar': 5},
        'y_2': {'value': 0.,  'step': -1, 'min': 0,   'max': 1, 'npar': 6},
        'z_2': {'value': 0.,  'step': -1, 'min': 0,   'max': 1, 'npar': 7},
        'x_3': {'value': 0.,  'step': -1, 'min': 0,   'max': 1, 'npar': 8},
        'y_3': {'value': 0.,  'step': -1, 'min': 0,   'max': 1, 'npar': 9},
        'z_3': {'value': 0.,  'step': -1, 'min': 0,   'max': 1, 'npar': 10},
        'x_4': {'value': 0.,  'step': -1, 'min': 0,   'max': 1, 'npar': 11},
        'y_4': {'value': 0.,  'step': -1, 'min': 0,   'max': 1, 'npar': 12},
        'z_4': {'value': 0.,  'step': -1, 'min': 0,   'max': 1, 'npar': 13},
        'x_5': {'value': 0.,  'step': -1, 'min': 0,   'max': 1, 'npar': 14},
        'y_5': {'value': 0.,  'step': -1, 'min': 0,   'max': 1, 'npar': 15},
        'z_5': {'value': 0.,  'step': -1, 'min': 0,   'max': 1, 'npar': 16},
        'x_6': {'value': 0.,  'step': -1, 'min': 0,   'max': 1, 'npar': 17},
        'y_6': {'value': 0.,  'step': -1, 'min': 0,   'max': 1, 'npar': 18},
        'z_6': {'value': 0.,  'step': -1, 'min': 0,   'max': 1, 'npar': 19},
        'x_7': {'value': 0.,  'step': -1, 'min': 0,   'max': 1, 'npar': 20},
        'y_7': {'value': 0.,  'step': -1, 'min': 0,   'max': 1, 'npar': 21},
        'z_7': {'value': 0.,  'step': -1, 'min': 0,   'max': 1, 'npar': 22},
    },
    livepoints=1000,                  # Number of live points
    search_method='SLICE_SAMPLING',   # Search method
    search_params=(0.5, 3),           # Parameters of chosen method
    conv_method='ENERGY_MAX',          # Selection method for the convergence criterion
    conv_accuracy=-10,                # log(Z) final accuracy
    conv_parameter=0.01,              # Minimal temperature valid for the calculation
)

# %%
# Run the code
t0 = time.perf_counter() # start timer

# For visualising the progress of the execution use this command
#out = conf.sample(output_mode='live')

# For visualising the progress graphycally (not working in Google Colab), use
# out = conf.sample(output_mode='full')

# If nothing shows, use simply the command (symlink to created or version to be used)
# Create the command to run nested fit in case of need
# run_nested_fit = os.system('nested_fit'+pynf.__version__)
# run_nested_fit

# For silently running the code and save the raw output in a dictionnary, use this command
out = conf.sample(output_mode='none')

t1 = time.perf_counter() # end timer

print(f"Nested sampling completed in {t1 - t0:.2f} seconds.")
# Out:
# Nested sampling completed in 15.31 seconds.

# %% [markdown]
# ## Visualize the results

# %%
# Load the nested output data
# The available parameters and other variables that can be plotted are listed
an=pynf.Analysis()
# Out:
# Current path =  .
# ['r_0', 'x_1', 'y_1', 'z_1', 'x_2', 'y_2', 'z_2', 'x_3', 'y_3', 'z_3', 'x_4', 'y_4', 'z_4', 'x_5', 'y_5', 'z_5', 'x_6', 'y_6', 'z_6', 'x_7', 'y_7', 'z_7']
# Index(['weight', 'lnlikelihood', 'r_0', 'x_1', 'y_1', 'z_1', 'x_2', 'y_2',
#        'z_2', 'x_3', 'y_3', 'z_3', 'x_4', 'y_4', 'z_4', 'x_5', 'y_5', 'z_5',
#        'x_6', 'y_6', 'z_6', 'x_7', 'y_7', 'z_7'],
#       dtype='str')
# Available parameters : ['weight', 'lnlikelihood', 'r_0', 'x_1', 'y_1', 'z_1', 'x_2', 'y_2', 'z_2', 'x_3', 'y_3', 'z_3', 'x_4', 'y_4', 'z_4', 'x_5', 'y_5', 'z_5', 'x_6', 'y_6', 'z_6', 'x_7', 'y_7', 'z_7']
# Index(['density', 'energy'], dtype='str')
# Available parameters: ['density', 'energy']
# Available energies: 94969

# %%
an.plot_weights()

# %%
# Plot the parameter convergence
# Colored regions correspond to the high value of the weights
an.plot_Cv(T_min=0.01,T_max=0.6,at_cluster=True,N=3)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/martino/Nextcloud/CNRS/work/programs/nested_fit/nested_fit/pynested_fit/nested_res.py:1532: RuntimeWarning: invalid value encountered in scalar divide
#   U[i] = np.sum(dos*en*np.exp(-en/T[i]))/Z[i] # Internal energy <E>
# /Users/martino/Nextcloud/CNRS/work/programs/nested_fit/nested_fit/pynested_fit/nested_res.py:1533: RuntimeWarning: invalid value encountered in scalar divide
#   en2 = np.sum(dos*en**2*np.exp(-en/T[i]))/Z[i] # <E^2>

# %% [markdown]
# # Lennar-Jones cluster with 17 atoms

# %% [markdown]
# ## Change directory and run the analysis

# %%
# Go to a define analysis
path = root_path+'/LJ17'


# Go to a define analysis
if not os.path.exists(path):
    os.makedirs(path)
os.chdir(path)

# %%
#### Define inputs using a "latex" function
conf = pynf.Configurator(
    calculation_mode= 'POTENTIAL',    # Calculation mode
    expressions=['ENERGY_LJ_3D_PBC'], # Chosen potential
    params={                          # Parameters of the potential
        'r_0': {'value': 0.5,  'step': -1, 'min': -3,   'max': 3, 'fixed': True, 'npar': 1},
        'x_1': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 2},
        'y_1': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 3},
        'z_1': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 4},
        'x_2': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 5},
        'y_2': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 6},
        'z_2': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 7},
        'x_3': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 8},
        'y_3': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 9},
        'z_3': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 10},
        'x_4': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 11},
        'y_4': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 12},
        'z_4': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 13},
        'x_5': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 14},
        'y_5': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 15},
        'z_5': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 16},
        'x_6': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 17},
        'y_6': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 18},
        'z_6': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 19},
        'x_7': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 20},
        'y_7': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 21},
        'z_7': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 22},
        'x_8': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 23},
        'y_8': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 24},
        'z_8': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 25},
        'x_9': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 26},
        'y_9': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 27},
        'z_9': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 28},
        'x_10': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 29},
        'y_10': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 30},
        'z_10': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 31},
        'x_11': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 32},
        'y_11': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 33},
        'z_11': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 34},
        'x_12': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 35},
        'y_12': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 36},
        'z_12': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 37},
        'x_13': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 38},
        'y_13': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 39},
        'z_13': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 40},
        'x_14': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 41},
        'y_15': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 42},
        'z_15': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 43},
        'x_16': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 44},
        'y_16': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 45},
        'z_16': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 46},
        'x_17': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 47},
        'y_17': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 48},
        'z_17': {'value': 0.,  'step': -1, 'min': -3,   'max': 3, 'npar': 49}
    },
    livepoints=50000,                  # Number of live points
    search_method='SLICE_SAMPLING',   # Search method
    search_params=(0.5, 3),           # Parameters of chosen method
    conv_method='ENERGY_MAX',          # Selection method for the convergence criterion
    conv_accuracy=-10,                # log(Z) final accuracy
    conv_parameter=0.01,              # Minimal temperature valid for the calculation
)

# %%
# Run the code

# For visualising the progress of the execution use this command
#out = conf.sample(output_mode='live')

# For visualising the progress graphycally (not working in Google Colab), use
# out = conf.sample(output_mode='full')

# If nothing shows, use simply the command (symlink to created or version to be used)
# Create the command to run nested fit in case of need
# run_nested_fit = os.system('nested_fit'+pynf.__version__)
# run_nested_fit

# For silently running the code and save the raw output in a dictionnary, use this command
out = conf.sample(output_mode='none')
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:15                                                                                   │
# │                                                                                                  │
# │   12 # run_nested_fit                                                                            │
# │   13                                                                                             │
# │   14 # For silently running the code and save the raw output in a dictionnary, use this comma    │
# │ ❱ 15 out = conf.sample(output_mode='none')                                                       │
# │   16                                                                                             │
# │                                                                                                  │
# ...

# %% [markdown]
# ## Visualize the results

# %%
# Load the nested output data
# The available parameters and other variables that can be plotted are listed
an=pynf.Analysis()
# Out:
# Current path =  .
# ['r_0', 'x_1', 'y_1', 'z_1', 'x_2', 'y_2', 'z_2', 'x_3', 'y_3', 'z_3', 'x_4', 'y_4', 'z_4', 'x_5', 'y_5', 'z_5', 'x_6', 'y_6', 'z_6', 'x_7', 'y_7', 'z_7']
# Index(['weight', 'lnlikelihood', 'r_0', 'x_1', 'y_1', 'z_1', 'x_2', 'y_2',
#        'z_2', 'x_3', 'y_3', 'z_3', 'x_4', 'y_4', 'z_4', 'x_5', 'y_5', 'z_5',
#        'x_6', 'y_6', 'z_6', 'x_7', 'y_7', 'z_7'],
#       dtype='str')
# Available parameters : ['weight', 'lnlikelihood', 'r_0', 'x_1', 'y_1', 'z_1', 'x_2', 'y_2', 'z_2', 'x_3', 'y_3', 'z_3', 'x_4', 'y_4', 'z_4', 'x_5', 'y_5', 'z_5', 'x_6', 'y_6', 'z_6', 'x_7', 'y_7', 'z_7']
# Index(['density', 'energy'], dtype='str')
# Available parameters: ['density', 'energy']
# Available energies: 96642

# %%
# Plot the parameter convergence
# Colored regions correspond to the high value of the weights
an.plot_Cv(T_min=0.01,T_max=0.6,at_cluster=True,N=3)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/martino/Nextcloud/CNRS/work/programs/nested_fit/nested_fit/pynested_fit/nested_res.py:1532: RuntimeWarning: invalid value encountered in scalar divide
#   U[i] = np.sum(dos*en*np.exp(-en/T[i]))/Z[i] # Internal energy <E>
# /Users/martino/Nextcloud/CNRS/work/programs/nested_fit/nested_fit/pynested_fit/nested_res.py:1533: RuntimeWarning: invalid value encountered in scalar divide
#   en2 = np.sum(dos*en**2*np.exp(-en/T[i]))/Z[i] # <E^2>
